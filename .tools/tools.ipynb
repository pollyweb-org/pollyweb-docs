# %% [markdown]
# Fix the malformed links.
# It may take a while if many links are broken.

# %%
# !python3 malformed-links.py
# Out:
# Project directory: /Users/jorgemf/Git/nlweb-docs
# ## Broken links found in the following files:
#
#
# In file: [ 05 🧭🫥 Navigator agent.md ](<../4 ⚙️ Solution/30 🫥 Agents/07 🧭 Navigators/05 🧭🫥 Navigator agent.md#L9>)
#   - Broken link : <../../../3 🤝 Use Cases/10 🍿 Entertainment/⏳ Go to Theaters 🎭/40 Viewer @ Seat/02 Wrong row.md>
#   - Tip         : Case mismatch?
#   - Suggestion  : <../../../../../../../3 🤝 Use Cases/10 🍿 Entertainment/Go to Theaters 🎭/40 Viewer @ Seat/02 Wrong row.md>
#   - Do you want to fix this link? (y/n):
